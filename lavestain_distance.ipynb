# %%
import pandas as pd
file_path=input("enter the file path")
file=pd.read_csv(file_path)
# Out:
# enter the file path/Users/laynewei/Desktop/Capstone/ctakes/input/2/combined_diseases.csv

# %%
file.head()
# Out:
#    note_id  file_name folder_path  \
# 0      661        661          2/
# 1      661        661          2/
# 2      661        661          2/
# 3      661        661          2/
# 4      661        661          2/
#
#                                       canon_text conditional       cui hof  \
# 0                                 Achondroplasia           f  C0001080   f
# 1  Deafness, Sensorineural, And Male Infertility           f  C1970187   f
# 2                 Hydrocephalus, Normal Pressure           f  C0020258   f
# 3                 Hydrocephalus, Normal Pressure           f  C0020258   f
# 4                         Food-Drug Interactions           f  C0242785   f
#
#   imputed_time location  location_snomed_id negated  offset_end  offset_start  \
# 0           na      NaN                 NaN       f          27            24
# 1           na      NaN                 NaN       f         105           102
# 2           na      NaN                 NaN       f        1255          1252
# 3           na      NaN                 NaN       f        1285          1282
# 4           na      NaN                 NaN       f        1481          1460
#
#               range_text  vocab_term        vocab value
# 0                    ACH    86268005  SNOMEDCT_US    na
# 1                    DIS   700489002  SNOMEDCT_US    na
# 2                    NPH    30753002  SNOMEDCT_US    na
# 3                    NPH    30753002  SNOMEDCT_US    na
# 4  Food/Drug Interaction    95907004  SNOMEDCT_US    na

# %%
canon_text,range_text=file['canon_text'],file['range_text']
string_1,string_2='',''
for i in canon_text:
    string_1=string_1+i+' '
for i in range_text:
    string_2=string_2+i+' '
print(string_1,'\n')
print(string_2)
# Out:
# Achondroplasia Deafness, Sensorineural, And Male Infertility Hydrocephalus, Normal Pressure Hydrocephalus, Normal Pressure Food-Drug Interactions Food-Drug Interactions Stomach Diseases Food-Drug Interactions Stomach Diseases Infections of musculoskeletal system Diabetes Mellitus, Non-Insulin-Dependent Bicuspid aortic valve Left Ventricular Hypertrophy Hypertensive disease Thyroglossal Cyst Coronary Artery Disease Kidney Failure, Chronic Kidney Failure, Chronic Congestive heart failure Heart failure Hyperlipidemia Hyperlipidemia Syphilis Syphilis Proline dehydrogenase deficiency Kidney Failure, Chronic Coronary Artery Disease Congestive heart failure Stomach Diseases Paroxysmal nocturnal dyspnea Spondyloenchondrodysplasia Hereditary Multiple Exostoses Left atrial hypertrophy Left Ventricular Hypertrophy Dehydration Pulmonary Edema Leukocyte adhesion deficiency type 1 Diabetes Mellitus, Non-Insulin-Dependent Deep Vein Thrombosis Infantile Neuroaxonal Dystrophy
#
# ACH DIS NPH NPH Food/Drug Interaction Food/Drug Interaction stomach Food/Drug Interaction stomach Infections NIDDM bicuspid aortic valve LVH HTN thyroglossal duct cyst cad ESRD end stage renal disease CHF heart failure hyperlipidemia hyperlipidemia syphilis syphilis HPI ESRD CAD CHF stomach PND SEM Ext LAE LVH dehydrated pulm edema LAD Mod DVT PLAN

# %%
import numpy
import sys

def levenshteinDistance(s1, s2):
    if len(s1) > len(s2):
        s1, s2 = s2, s1

    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]

import re
lab = re.sub('[!#?,.:";]', '', string_1) 
msg = re.sub('[!#?,.:";]', '', string_2) 

result = levenshteinDistance(lab, msg)
bigger = max(len(lab), len(msg))
result = ((bigger - result) / bigger) * 100
print('Accuracy : %.2f%%'%(result))
# Out:
# Accuracy : 29.22%

# %%
for i in range(len(file['canon_text'])):
    a=file['canon_text'][i].lower()
    b=file['range_text'][i].lower()
    import re
    lab = re.sub('[!#?,.:";/-]', '', a) 
    msg = re.sub('[!#?,.:";/-]', '', b) 

    result = levenshteinDistance(lab, msg)
    bigger = max(len(lab), len(msg))
    result = ((bigger - result) / bigger) * 100
    print('Canon_text:',file['canon_text'][i],'********','Range_text:',file['range_text'][i],'*********','Accuracy : %.2f%%'%(result))
# Out:
# Canon_text: Achondroplasia ******** Range_text: ACH ********* Accuracy : 21.43%
# Canon_text: Deafness, Sensorineural, And Male Infertility ******** Range_text: DIS ********* Accuracy : 4.65%
# Canon_text: Hydrocephalus, Normal Pressure ******** Range_text: NPH ********* Accuracy : 6.90%
# Canon_text: Hydrocephalus, Normal Pressure ******** Range_text: NPH ********* Accuracy : 6.90%
# Canon_text: Food-Drug Interactions ******** Range_text: Food/Drug Interaction ********* Accuracy : 95.24%
# Canon_text: Food-Drug Interactions ******** Range_text: Food/Drug Interaction ********* Accuracy : 95.24%
# Canon_text: Stomach Diseases ******** Range_text: stomach ********* Accuracy : 43.75%
# Canon_text: Food-Drug Interactions ******** Range_text: Food/Drug Interaction ********* Accuracy : 95.24%
# Canon_text: Stomach Diseases ******** Range_text: stomach ********* Accuracy : 43.75%
# Canon_text: Infections of musculoskeletal system ******** Range_text: Infections ********* Accuracy : 27.78%
# Canon_text: Diabetes Mellitus, Non-Insulin-Dependent ******** Range_text: NIDDM ********* Accuracy : 10.81%
# Canon_text: Bicuspid aortic valve ******** Range_text: bicuspid aortic valve ********* Accuracy : 100.00%
# Canon_text: Left Ventricular Hypertrophy ******** Range_text: LVH ********* Accuracy : 10.71%
# Canon_text: Hypertensive disease ******** Range_text: HTN ********* Accuracy : 15.00%
# Canon_text: Thyroglossal Cyst ******** Range_text: thyroglossal duct cyst ********* Accuracy : 77.27%
# Canon_text: Coronary Artery Disease ******** Range_text: cad ********* Accuracy : 13.04%
# Canon_text: Kidney Failure, Chronic ******** Range_text: ESRD ********* Accuracy : 9.09%
# Canon_text: Kidney Failure, Chronic ******** Range_text: end stage renal disease ********* Accuracy : 13.04%
# Canon_text: Congestive heart failure ******** Range_text: CHF ********* Accuracy : 12.50%
# Canon_text: Heart failure ******** Range_text: heart failure ********* Accuracy : 100.00%
# Canon_text: Hyperlipidemia ******** Range_text: hyperlipidemia ********* Accuracy : 100.00%
# Canon_text: Hyperlipidemia ******** Range_text: hyperlipidemia ********* Accuracy : 100.00%
# Canon_text: Syphilis ******** Range_text: syphilis ********* Accuracy : 100.00%
# Canon_text: Syphilis ******** Range_text: syphilis ********* Accuracy : 100.00%
# Canon_text: Proline dehydrogenase deficiency ******** Range_text: HPI ********* Accuracy : 6.25%
# Canon_text: Kidney Failure, Chronic ******** Range_text: ESRD ********* Accuracy : 9.09%
# Canon_text: Coronary Artery Disease ******** Range_text: CAD ********* Accuracy : 13.04%
# Canon_text: Congestive heart failure ******** Range_text: CHF ********* Accuracy : 12.50%
# Canon_text: Stomach Diseases ******** Range_text: stomach ********* Accuracy : 43.75%
# Canon_text: Paroxysmal nocturnal dyspnea ******** Range_text: PND ********* Accuracy : 10.71%
# Canon_text: Spondyloenchondrodysplasia ******** Range_text: SEM ********* Accuracy : 7.69%
# Canon_text: Hereditary Multiple Exostoses ******** Range_text: Ext ********* Accuracy : 10.34%
# Canon_text: Left atrial hypertrophy ******** Range_text: LAE ********* Accuracy : 13.04%
# Canon_text: Left Ventricular Hypertrophy ******** Range_text: LVH ********* Accuracy : 10.71%
# Canon_text: Dehydration ******** Range_text: dehydrated ********* Accuracy : 72.73%
# Canon_text: Pulmonary Edema ******** Range_text: pulm edema ********* Accuracy : 66.67%
# Canon_text: Leukocyte adhesion deficiency type 1 ******** Range_text: LAD ********* Accuracy : 8.33%
# Canon_text: Diabetes Mellitus, Non-Insulin-Dependent ******** Range_text: Mod ********* Accuracy : 8.11%
# Canon_text: Deep Vein Thrombosis ******** Range_text: DVT ********* Accuracy : 15.00%
# Canon_text: Infantile Neuroaxonal Dystrophy ******** Range_text: PLAN ********* Accuracy : 9.68%

# %%
# Out:
#        note_id  file_name  location_snomed_id   offset_end  offset_start  \
# count     40.0       40.0        9.000000e+00    40.000000      40.00000
# mean     661.0      661.0        1.548848e+08  3425.325000    3417.55000
# std        0.0        0.0        1.026978e+08  1475.193015    1476.65311
# min      661.0      661.0        4.180101e+07    27.000000      24.00000
# 25%      661.0      661.0        6.403301e+07  3049.000000    3042.75000
# 50%      661.0      661.0        1.812460e+08  3327.000000    3313.50000
# 75%      661.0      661.0        1.812460e+08  4166.000000    4163.00000
# max      661.0      661.0        3.430110e+08  6963.000000    6959.00000
#
#          vocab_term
# count  4.000000e+01
# mean   1.693627e+12
# std    1.071078e+13
# min    1.924201e+07
# 25%    4.234301e+07
# 50%    5.582450e+07
# 75%    9.590700e+07
# max    6.774100e+13
